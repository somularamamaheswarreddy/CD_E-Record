# %%
# Install PLY
# !pip install ply

import ply.lex as lex

# Fix for Jupyter
__file__ = "lexer.py"

tokens = ['VOWEL', 'CONSONANT']

def t_VOWEL(t):
    r'[aeiouAEIOU]'
    return t

def t_CONSONANT(t):
    r'[b-df-hj-np-tv-zB-DF-HJ-NP-TV-Z]'
    return t

t_ignore = ' \t\n'

def t_error(t):
    t.lexer.skip(1)

lexer = lex.lex()

lexer.input("Bakery")

for tok in lexer:
    print(tok)
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 838.2 kB/s eta 0:00:00
# ...
# LexToken(CONSONANT,'B',1,0)
# LexToken(VOWEL,'a',1,1)
# LexToken(CONSONANT,'k',1,2)
# LexToken(VOWEL,'e',1,3)
# LexToken(CONSONANT,'r',1,4)
# LexToken(CONSONANT,'y',1,5)
